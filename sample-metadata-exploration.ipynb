# %%
import pandas as pd
import numpy as np
sample_md = pd.read_csv("./master-map.tsv", sep='\t', index_col="#SampleID").replace("no_data", np.nan).convert_objects(convert_numeric=True)
# Out:
# /home/gregcaporaso/.conda/envs/data-analysis/lib/python3.5/site-packages/IPython/kernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()

# %%
list(sample_md.columns)
# Out:
# ['BarcodeSequence',
#  'LinkerPrimerSequence',
#  'OTU-WeightedUniFrac-PC1',
#  'OTU-UnweightedUniFrac-PC1',
#  'OTU-PD',
#  'Derep-WeightedUniFrac-PC1',
#  'Derep-WeightedUniFrac-PC2',
#  'Derep-WeightedUniFrac-PC3',
#  'Derep-UnweightedUniFrac-PC1',
#  'Derep-UnweightedUniFrac-PC2',
#  'Derep-UnweightedUniFrac-PC3',
#  'Derep-PD',
#  'MiSeqRun',
#  'control',
#  'ptid',
#  'nau_id',
#  'visit',
#  'treatmentgroup',
#  'pre_date_startcol',
#  'pre_date_endcol',
#  'pre_date_process',
#  'pre_col_days',
#  'post_date_startcol',
#  'post_date_endcol',
#  'post_date_process',
#  'post_col_days',
#  'col_timegap',
#  'proc_timegap',
#  'rs13161018',
#  'has_rs13161018',
#  'odc1',
#  'pre_tac_lc',
#  'pre_tac_dc',
#  'pre_tac_cd',
#  'pre_tac_ca',
#  'pre_tac_ud',
#  'pre_tac_uc',
#  'pre_tac_ot',
#  'pre_tacids',
#  'pre_tac_primary',
#  'pre_tac_secondary',
#  'pre_tac_tertiary',
#  'pre_tac_hydrophobic',
#  'pre_tac_hydrophilic',
#  'post_tac_lc',
#  'post_tac_dc',
#  'post_tac_cd',
#  'post_tac_ca',
#  'post_tac_ud',
#  'post_tac_uc',
#  'post_tac_ot',
#  'post_tacids',
#  'post_tac_primary',
#  'post_tac_secondary',
#  'post_tac_tertiary',
#  'post_tac_hydrophobic',
#  'post_tac_hydrophilic',
#  'hrrecrx',
#  'treatudca',
#  'pre_largest',
#  'pre_large',
#  'pre_number',
#  'pre_mult',
#  'pre_dist',
#  'pre_prox',
#  'pre_villous',
#  'male',
#  'age',
#  'white',
#  'grade',
#  'weight',
#  'height',
#  'bmi',
#  'waist',
#  'hip',
#  'whr',
#  'systolbp',
#  'diastlbp',
#  'smokenow',
#  'eversmoke',
#  'aspirin',
#  'prevplyp',
#  'famhxcrc',
#  'hhdiabete',
#  'glucose',
#  'trig',
#  'hdl',
#  'post_recur',
#  'post_cancer',
#  'post_largest',
#  'post_large',
#  'post_number',
#  'post_mult',
#  'post_dist',
#  'post_prox',
#  'post_villous',
#  'post_advanced',
#  'prot',
#  'tfat',
#  'carb',
#  'ener',
#  'alco',
#  'tfib',
#  'calc',
#  'magn',
#  'fola',
#  'sfat',
#  'mufa',
#  'pufa',
#  'sfolat',
#  'scalc',
#  'suppuse',
#  'redmeat',
#  'sucr',
#  'gluc',
#  'fruc',
#  'lact',
#  'malt',
#  'suga',
#  'gala',
#  'argi',
#  'putrescine',
#  'spermidine',
#  'spermine',
#  'poly',
#  'Days_Since_Epoch',
#  'Description1',
#  'Description',
#  'Begin_collect_date']

# %%
sample_md.groupby(['male', 'treatmentgroup', 'visit']).count()
# Out:
#                            BarcodeSequence  LinkerPrimerSequence  \
# male treatmentgroup visit
# 0.0  UDCA           post                63                    63
#                     pre                 65                    65
#      placebo        post                90                    90
#                     pre                 88                    88
# 1.0  UDCA           post               190                   190
#                     pre                186                   186
#      placebo        post               161                   161
#                     pre                163                   163
#
#                            OTU-WeightedUniFrac-PC1  OTU-UnweightedUniFrac-PC1  \
# male treatmentgroup visit
# 0.0  UDCA           post                        53                         53
#                     pre                         50                         50
#      placebo        post                        77                         77
#                     pre                         66                         66
# 1.0  UDCA           post                       164                        164
#                     pre                        133                        133
#      placebo        post                       143                        143
#                     pre                        124                        124
#
#                            OTU-PD  Derep-WeightedUniFrac-PC1  \
# male treatmentgroup visit
# 0.0  UDCA           post       53                         57
#                     pre        50                         53
#      placebo        post       77                         84
#                     pre        66                         75
# 1.0  UDCA           post      164                        184
#                     pre       133                        151
#      placebo        post      143                        159
#                     pre       124                        138
#
#                            Derep-WeightedUniFrac-PC2  \
# male treatmentgroup visit
# 0.0  UDCA           post                          57
#                     pre                           53
#      placebo        post                          84
#                     pre                           75
# 1.0  UDCA           post                         184
#                     pre                          151
#      placebo        post                         159
#                     pre                          138
#
#                            Derep-WeightedUniFrac-PC3  \
# male treatmentgroup visit
# 0.0  UDCA           post                          57
#                     pre                           53
#      placebo        post                          84
#                     pre                           75
# 1.0  UDCA           post                         184
#                     pre                          151
#      placebo        post                         159
#                     pre                          138
#
#                            Derep-UnweightedUniFrac-PC1  \
# male treatmentgroup visit
# 0.0  UDCA           post                            57
#                     pre                             53
#      placebo        post                            84
#                     pre                             75
# 1.0  UDCA           post                           184
#                     pre                            151
#      placebo        post                           159
#                     pre                            138
#
#                            Derep-UnweightedUniFrac-PC2         ...          \
# male treatmentgroup visit                                      ...
# 0.0  UDCA           post                            57         ...
#                     pre                             53         ...
#      placebo        post                            84         ...
#                     pre                             75         ...
# 1.0  UDCA           post                           184         ...
#                     pre                            151         ...
#      placebo        post                           159         ...
#                     pre                            138         ...
#
#                            gala  argi  putrescine  spermidine  spermine  poly  \
# male treatmentgroup visit
# 0.0  UDCA           post     63    63          63          63        63    63
#                     pre      65    65          65          65        65    65
#      placebo        post     90    90          90          90        90    90
#                     pre      88    88          88          88        88    88
# 1.0  UDCA           post    190   190         190         190       190   190
#                     pre     186   186         186         186       186   186
#      placebo        post    161   161         161         161       161   161
#                     pre     163   163         163         163       163   163
#
#                            Days_Since_Epoch  Description1  Description  \
# male treatmentgroup visit
# 0.0  UDCA           post                 11            43           63
#                     pre                  14            45           65
#      placebo        post                 16            67           90
#                     pre                  13            63           88
# 1.0  UDCA           post                 19           151          190
#                     pre                  14           141          186
#      placebo        post                 15           121          161
#                     pre                  17           118          163
#
#                            Begin_collect_date
# male treatmentgroup visit
# 0.0  UDCA           post                   62
#                     pre                    65
#      placebo        post                   89
#                     pre                    88
# 1.0  UDCA           post                  188
#                     pre                   186
#      placebo        post                  159
#                     pre                   163
#
# [8 rows x 126 columns]
